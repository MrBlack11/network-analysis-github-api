# %% [markdown]
# # Network Analysis - Generate a interest graph using the GitHub API
# Bom, nesse artigo iremos adentrar no estudos de análises em rede utilizando python, em especial gerar um grafo de interesse para extrair algumas análises. No nosso caso de estudos usaremos a API do GitHub e um repositório de código aberto, selecionaremos quem o "segue" e veremos se esses usuários possuem relação entre si. Here we go...

# %% [markdown]
# ## 1 Obter acesso à API do GitHub
# Existem duas formas de obter esse acesso, criando um repositório responsável por acessar a api ou gerando um token pessoal para isso. Vamos optar pela segunda opção. Ainda, temos a opção de gerar esse token via interface de usuário ou programaticamente. Vamos utilizar o método programático (e mais legal, off course).

# %%
# instalando a lib requests
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (2.21.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests) (2.8)

# %%
# obtendo token de acesso programaticamente
import requests
import json

# credenciais da conta
username = '' # you github username
password = '' # you github password

url = 'https://api.github.com/authorizations'
note = 'Mining repositories to network analysis'
post_data = {'scopes': ['repo'], 'note': note}

response  = requests.get(url,
                        auth = (username, password),
                        data = json.dumps(post_data)
                       )

print("API response: ", response.text)
print("Your OAuth token is: ", response.json()[0]['hashed_token'])
# Out:
# API response:  [{"id":260105660,"url":"https://api.github.com/authorizations/260105660","app":{"name":"git: https://github.com/ on M40893 at 11-fev-2019 12:25","url":"https://developer.github.com/v3/oauth_authorizations/","client_id":"00000000000000000000"},"token":"","hashed_token":"20939728e30431899de75d8543062af879334a0a051e5c7e7778ebb571fcb000","token_last_eight":"6e0fbb26","note":"git: https://github.com/ on M40893 at 11-fev-2019 12:25","note_url":null,"created_at":"2019-02-11T15:25:59Z","updated_at":"2019-02-11T15:25:59Z","scopes":["gist","repo"],"fingerprint":null},{"id":301738068,"url":"https://api.github.com/authorizations/301738068","app":{"name":"Mining repositories to network analysis","url":"https://developer.github.com/v3/oauth_authorizations/","client_id":"00000000000000000000"},"token":"","hashed_token":"c33390a4e22bce805aac846611f6bed3a14295203885eaccfeb3a7e367052f63","token_last_eight":"8a1c821e","note":"Mining repositories to network analysis","note_url":null,"created_at":"2019-06-23T20:17:17Z","updated_at":"2019-06-23T20:17:17Z","scopes":["repo"],"fingerprint":null},{"id":216316118,"url":"https://api.github.com/authorizations/216316118","app":{"name":"Cloud9","url":"https://c9.io","client_id":"e17d0b327cd114a08bb4"},"token":"","hashed_token":"2c0700a429f7dc6051f34cc648cd7e61725cbdb1956854a821191a57718f157e","token_last_eight":"1c58e497","note":null,"note_url":null,"created_at":"2018-09-03T16:52:24Z","updated_at":"2018-09-03T16:52:25Z","scopes":["repo","user:email","write:public_key"],"fingerprint":null},{"id":216316158,"url":"https://api.github.com/authorizations/216316158","app":{"name":"Cloud9","url":"https://c9.io","client_id":"e17d0b327cd114a08bb4"},"token":"","hashed_token":"04e568c7962b5a31eac6e47cbe3e3d5428b52735829a982e9fcd3343d5d35421","token_last_eight":"ca7ab97f","note":null,"note_url":null,"created_at":"2018-09-03T16:52:39Z","updated_at":"2018-09-03T16:52:39Z","scopes":["repo","user:email","write:public_key"],"fingerprint":null},{"id":216316232,"url":"https://api.github.com/authorizations/216316232","app":{"name":"Cloud9","url":"https://c9.io","client_id":"e17d0b327cd114a08bb4"},"token":"","hashed_token":"bee3f706443ac9db5296296e5982395bde0a95a3ff5d41662a6eb4b5bc6d639f","token_last_eight":"3729c5f4","note":null,"note_url":null,"created_at":"2018-09-03T16:53:03Z","updated_at":"2018-09-03T16:53:03Z","scopes":["repo","user:email","write:public_key"],"fingerprint":null},{"id":257194879,"url":"https://api.github.com/authorizations/257194879","app":{"name":"CodePen.io","url":"https://codepen.io","client_id":"1d46d447dfcd2ccd7b18"},"token":"","hashed_token":"aa384d4db9ece050ed488fdfc3f89d9b55f711a8c917b4c07e5990454ba323f1","token_last_eight":"f835709d","note":null,"note_url":null,"created_at":"2019-01-31T14:36:28Z","updated_at":"2019-01-31T14:36:30Z","scopes":["gist","user:email"],"fingerprint":null},{"id":257293909,"url":"https://api.github.com/authorizations/257293909","app":{"name":"CodePen.io","url":"https://codepen.io","client_id":"1d46d447dfcd2ccd7b18"},"token":"","hashed_token":"9110a2f7de0badfd439d03f14f305b6d469301e07e9ccb52df311a2658540213","token_last_eight":"036e5d99","note":null,"note_url":null,"created_at":"2019-01-31T20:23:07Z","updated_at":"2019-01-31T20:23:08Z","scopes":["gist","user:email"],"fingerprint":null},{"id":219837109,"url":"https://api.github.com/authorizations/219837109","app":{"name":"Gist","url":"https://gist.github.com","client_id":"7e0a3cd836d3e544dbd9"},"token":"","hashed_token":"836dcf3b473650587ab00227c726fbac789e63fec74d26e5b0bfaa39515ff788","token_last_eight":"5b085d88","note":null,"note_url":null,"created_at":"2018-09-16T18:16:50Z","updated_at":"2018-09-16T18:16:50Z","scopes":[],"fingerprint":null},{"id":229314122,"url":"https://api.github.com/authorizations/229314122","app":{"name":"Gist","url":"https://gist.github.com","client_id":"7e0a3cd836d3e544dbd9"},"token":"","hashed_token":"30c3d214afb34bf6abc7d40eec14b039818688c8742dbcbd393ca405904e47fe","token_last_eight ...
# Your OAuth token is:  20939728e30431899de75d8543062af879334a0a051e5c7e7778ebb571fcb000

# %% [markdown]
# ## 2 Gerando grafo de stargazers
# Vamos gerar um grafo dos "stargazers" (vulgo perseguidores de estrelas (?)). Iremos utilizar alguma libs python aqui para nos auxiliar no processo. Para a manipulação de grafos usáremos o [Networkx](https://networkx.github.io/) e a [PyGithub](https://pygithub.readthedocs.io/en/latest/) para facilitar os acessos a api do github. As outras depedências que forem necessárias seram citadas no decorrer do texto.

# %% [markdown]
# ### 2.1 Obtendo stargazers
# Como em geral não a biblioteca PyGithub não vem instalada, precisamos instalar com o comando:

# %%
# instalar PyGithub
# !pip install PyGithub
# Out:
# Collecting PyGithub
#   Downloading https://files.pythonhosted.org/packages/f7/48/ec5ef5239f3a4043ee7e07b454b5f3a024a5f22a4e585400ac6caa22c3c4/PyGithub-1.43.7.tar.gz (107kB)
#      |████████████████████████████████| 112kB 4.2MB/s
# Collecting deprecated (from PyGithub)
#   Downloading https://files.pythonhosted.org/packages/9f/7a/003fa432f1e45625626549726c2fbb7a29baa764e9d1fdb2323a5d779f8a/Deprecated-1.2.5-py2.py3-none-any.whl
# Collecting pyjwt (from PyGithub)
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.6/dist-packages (from PyGithub) (2.21.0)
# Requirement already satisfied: wrapt<2,>=1 in /usr/local/lib/python3.6/dist-packages (from deprecated->PyGithub) (1.11.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.14.0->PyGithub) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.14.0->PyGithub) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.14.0->PyGithub) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.14.0->PyGithub) (1.24.3)
# Building wheels for collected packages: PyGithub
#   Building wheel for PyGithub (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/41/a2/13/f40c7a91db4b3743ef1830234526054d62f8c502510f3eb18a
# Successfully built PyGithub
# Installing collected packages: deprecated, pyjwt, PyGithub
# Successfully installed PyGithub-1.43.7 deprecated-1.2.5 pyjwt-1.7.1

# %% [markdown]
# Precisamo escolher um repositório. Escolhi o [Mining-the-Social-Web ](https://github.com/ptwobrussell/Mining-the-Social-Web) do [ptwobrussell](https://github.com/ptwobrussell) para realizar nosso estudo, pois é um repositório com um número não muito grande de "seguidores", facilitando na exibição do grafo. Mas fique a vontade para escolher qualquer um de sua preferência. Na *seção 1* obtemos um token de acesso para api do github. É aqui que precisaremos dela.

# %%
# import ygithub
from github import Github

# especificar meu token de acesso
ACCESS_TOKEN = ''

# especificando um usuário e um repositório de interesse
USER = 'ptwobrussell'
REPO = 'Mining-the-Social-Web'

# autenticando na api do github
client = Github(ACCESS_TOKEN, per_page=100)

# especificando usuário que estamos buscando: ptwobrussell
user = client.get_user(USER)

# acessando o nosso repositório: Mining-the-Social-Web 
repo = user.get_repo(REPO)

# obtendo stargazers do repositório
stargazers = [s for s in repo.get_stargazers()]
print("Number of stargazers", len(stargazers))

# lista de stargazers
print(stargazers)
# Out:
# Number of stargazers 1182
# [NamedUser(login="rdempsey"), NamedUser(login="frac"), NamedUser(login="prb"), NamedUser(login="mcroydon"), NamedUser(login="batasrki"), NamedUser(login="twleung"), NamedUser(login="kevinchiu"), NamedUser(login="nikolay"), NamedUser(login="tswicegood"), NamedUser(login="ngpestelos"), NamedUser(login="darron"), NamedUser(login="brunojm"), NamedUser(login="rgaidot"), NamedUser(login="openweb"), NamedUser(login="shanlalit"), NamedUser(login="hoffmann"), NamedUser(login="nacht"), NamedUser(login="hectoregm"), NamedUser(login="tzuryby"), NamedUser(login="marksands"), NamedUser(login="wbzyl"), NamedUser(login="sou"), NamedUser(login="magnum"), NamedUser(login="suzuki"), NamedUser(login="tertsch"), NamedUser(login="ymirpl"), NamedUser(login="sebasmagri"), NamedUser(login="galvez"), NamedUser(login="paulbersch"), NamedUser(login="georgebellos"), NamedUser(login="acadopia"), NamedUser(login="ggtr1138"), NamedUser(login="program247365"), NamedUser(login="edwelker"), NamedUser(login="hammer"), NamedUser(login="jengdal"), NamedUser(login="brimbrom"), NamedUser(login="gar"), NamedUser(login="willi"), NamedUser(login="gregmoreno"), NamedUser(login="rays"), NamedUser(login="rayleyva"), NamedUser(login="paxan"), NamedUser(login="eughenes"), NamedUser(login="barce"), NamedUser(login="abuiles"), NamedUser(login="carhartl"), NamedUser(login="jexchan"), NamedUser(login="yasu00000"), NamedUser(login="lsinger"), NamedUser(login="yy"), NamedUser(login="daemianmack"), NamedUser(login="ricardoalmeida"), NamedUser(login="gerad"), NamedUser(login="amitagrawal"), NamedUser(login="swinton"), NamedUser(login="polonia"), NamedUser(login="fozbaca"), NamedUser(login="nborwankar"), NamedUser(login="macdet"), NamedUser(login="Smerity"), NamedUser(login="joepestro"), NamedUser(login="phauly"), NamedUser(login="shamiksharma"), NamedUser(login="lg2046"), NamedUser(login="omg"), NamedUser(login="lzell"), NamedUser(login="eduardocereto"), NamedUser(login="kshimo69"), NamedUser(login="natorro"), NamedUser(login="abecciu"), NamedUser(login="CaptSolo"), NamedUser(login="clyfe"), NamedUser(login="mahmoudimus"), NamedUser(login="mznmel"), NamedUser(login="Kilian"), NamedUser(login="stonegao"), NamedUser(login="pcdinh"), NamedUser(login="jacktang"), NamedUser(login="Almad"), NamedUser(login="sleeptillseven"), NamedUser(login="Kudo"), NamedUser(login="acdha"), NamedUser(login="ticean"), NamedUser(login="buffpojken"), NamedUser(login="bnvk"), NamedUser(login="zen4ever"), NamedUser(login="bpeirce"), NamedUser(login="metllord"), NamedUser(login="macdiva"), NamedUser(login="miukal"), NamedUser(login="miyucy"), NamedUser(login="valentinzberea"), NamedUser(login="Tuxified"), NamedUser(login="miku"), NamedUser(login="daevid"), NamedUser(login="lemonad"), NamedUser(login="Xeoncross"), NamedUser(login="shurik"), NamedUser(login="zonovo"), NamedUser(login="matagus"), NamedUser(login="phernandez"), NamedUser(login="vshulyak"), NamedUser(login="elg0nz"), NamedUser(login="jonathanjo"), NamedUser(login="rduong"), NamedUser(login="sfrench"), NamedUser(login="edtechdev"), NamedUser(login="vvoody"), NamedUser(login="riivo"), NamedUser(login="doolin"), NamedUser(login="even4void"), NamedUser(login="lrvick"), NamedUser(login="cameronpriest"), NamedUser(login="napo"), NamedUser(login="ukituki"), NamedUser(login="blynch"), NamedUser(login="adriaant"), NamedUser(login="mgrouchy"), NamedUser(login="InFog"), NamedUser(login="rnagle"), NamedUser(login="macorama"), NamedUser(login="mki"), NamedUser(login="dasfaha"), NamedUser(login="jagguli"), NamedUser(login="davidrd123"), NamedUser(login="darkseed"), NamedUser(login="bjpcjp"), NamedUser(login="jonathanyee"), NamedUser(login="jensenrf"), NamedUser(login="levigross"), NamedUser(login="BrianPin"), NamedUser(login="nycterent"), NamedUser(login="lyddonb"), NamedUser(login="putorti"), NamedUser(login="vigo"), NamedUser(login="MaggiePlusPlus"), NamedUser(login="Stecki"), NamedUser(login="jean"), NamedUser(login="ido"), NamedUser(login="brianly"), NamedU ...

# %% [markdown]
# ### 2.2 Networkx
# Agora podemos criar nosso grafo utilizando como base nosso repositório e seus stargazers. Vamos fazer aqui uma distinção entre repositório e usuário pois, é bastante comum existir repositórios com o mesmo nome de usuários. Para isso vamos adicionar o pós-fixo "(user)" para usuário e "(repo)" para repositório. Aqui vamos utilizar o Networkx, sua utilização é simples, porém bastante poderosa. Vamos criar nosso grafo...

# %%
import networkx as nx

# cria novo grafo direcionado (DiGraph)
graph = nx.DiGraph()
graph.name = "Interest graph of a repo"

# adicionando o node repositório 'requests'
graph.add_node(repo.name + '(repo)', type='repo', lang=repo.language, owner=user.login)

# adicionando node de stargazers e edges com repositório
for stargazer in stargazers:
  graph.add_node(stargazer.login + '(user)', type="user")
  graph.add_edge(stargazer.login + '(user)', repo.name + '(repo)', type="gazes")
  
# obtendo informações do grafo
print(nx.info(graph))
# Out:
# Name: Interest graph of a repo
# Type: DiGraph
# Number of nodes: 1183
# Number of edges: 1182
# Average in degree:   0.9992
# Average out degree:   0.9992

# %% [markdown]
# Vemos que nosso grafo tem um número não muito grande de nós: 1183. Com nosso grafo criado, podemos fazer nossa primeira visualização. É importante ressaltar que o Networkx não foi desenvolvido para trabalhar com visualização de grafos, apenas com sua manipulação. Então, iremos utilizar um software externo para gerar uma visualização mais amigável. Não vou entrar em detalhes sobre o gephi, pois não é esse o foco do artigo. Qualquer dúvida, veja a [documentação](https://gephi.org/users/) da ferramenta

# %%
# !pip install git+https://github.com/ericmjl/nxviz

# %%
import matplotlib.pyplot as plt
from nxviz import CircosPlot

c = CircosPlot(graph, 
               node_color='type',
               node_order='type',
               figsize=(30, 30),
               nodeprops={"radius": 1},
               fontsize = 12
              )

c.draw()
c.figure.tight_layout()

plt.show()

# %% [markdown]
# Isso pode levar algum tempo, devido a quantidade de nós no grafo. Mas temos uma alternativa também, até visualmente melhor: o Gephi. O networkx permite exportar o grafo com a extensão .graphml e com isso é possível realizar a leitura no Gephi.

# %%
nx.write_graphml(graph, "first.graphml")

# %% [markdown]
# ### 2.3 Adicionando seguidores ao ao grafo
# Para reduzir nosso escopo, vamos adicionar apenas os seguidores dos nossos usuários que possuem interesse no repositório. Isso facilita nosso trabalho, pois lembramos que a api do github só libera 5000 requisições por hora, e iremos precisar mais adiante.

# %%
# percorrendo stargazers
for i, stargazer in enumerate(stargazers):
  try: 
    for follower in stargazer.get_followers():
      # se estiver no grafo, adicione uma edge com o perfil que ele segue
      if follower.login + '(user)' in graph:
        graph.add_edge(follower.login + '(user)', stargazer.login + '(user)', type="follows")
  except Exception as e:
    print("Ocorreu um erro buscando seguidores para ", stargazer.login, "Pulando...")
    
  print("Processados", i+1, "stargazers. Números de nodes/edges", graph.number_of_nodes(), graph.number_of_edges())
  print("Requisições restantes:", client.rate_limiting)
# Out:
# Processados 1 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4943, 5000)
# Processados 2 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4942, 5000)
# Processados 3 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4941, 5000)
# Processados 4 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4939, 5000)
# Processados 5 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4938, 5000)
# Processados 6 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4937, 5000)
# Processados 7 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4936, 5000)
# Processados 8 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4932, 5000)
# Processados 9 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4927, 5000)
# Processados 10 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4926, 5000)
# Processados 11 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4925, 5000)
# Processados 12 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4924, 5000)
# Processados 13 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4923, 5000)
# Processados 14 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4921, 5000)
# Processados 15 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4920, 5000)
# Processados 16 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4918, 5000)
# Processados 17 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4917, 5000)
# Processados 18 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4916, 5000)
# Processados 19 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4915, 5000)
# Processados 20 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4913, 5000)
# Processados 21 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4910, 5000)
# Processados 22 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4909, 5000)
# Processados 23 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4908, 5000)
# Processados 24 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4907, 5000)
# Processados 25 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4906, 5000)
# Processados 26 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4905, 5000)
# Processados 27 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4903, 5000)
# Processados 28 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4901, 5000)
# Processados 29 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4900, 5000)
# Processados 30 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4899, 5000)
# Processados 31 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4898, 5000)
# Processados 32 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4897, 5000)
# Processados 33 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4896, 5000)
# Processados 34 stargazers. Números de nodes/edges 1183 1286
# Requisições restantes: (4895, 5000)
# Processados 35 stargazers. Números de nodes/edges 1183 1288
# Requisições restantes: (4887, 5000)
# Processados 36 stargazers. Números de nodes/edges 1183 1289
# Requisições restantes: (4886, 5000)
# Processados 37 stargazers. Números de nodes/edges 1183 1291
# Requisições restantes: (4885, 5000)
# Processados 38 stargazers. Números de nodes/edges 1183 1292
# Requisições restantes: (4884, 5000)
# Processados 39 stargazers. Números de nodes/edges 1183 1295
# Requisições restantes: (4882, 5000)
# Processados 40 stargazers. Números de nodes/edges 1183 1298
# Requisições restantes: (4881, 5000)
# Processados 41 stargazers. Números de nodes/edges 1183 1299
# Requisições restantes: (4880, 5000)
# Processados 42 stargazers. Números de nodes/edges 1183 1301
# Requisições restantes: (4879, 5000)
# Processados 43 stargazers. Números de nodes/edges 1183 1303
# Requisições restantes: (4878, 5000)
# Processados 44 stargazers. Números de nodes/edges 1183 1304
# Requisições restantes: (4877, 5000)
# Processados 45 stargazers. Números de nodes/edges 1183 1307
# Requisições restantes: (4876, 5000)
# Processados 46 stargazers. Números de nodes/edges 1183 1310
# Requisições restantes: (4873, 5000)
# Processados 47 stargazers. Números de nodes/edges 1183 1314
# Requisições restantes: (4870, 5000)
# Processados 48 stargazers. Números de nodes/edges 1183 1316
# Requisições restantes: (4869, 5000)
# Processados 49 stargazers. Números de nodes/edges 1183 1317
# Requisições restantes: (4868, 5000)
# Processados 50 stargazers. Números de nodes/edges 1183 1318
# Requisições restantes: (4867, 5000)
# Processados 51 stargazers. Números de nodes/edges 1183 1319
# Requisições restantes: (4866, 5000)
# Processados 52 stargazers. Números de nodes/edges 1183 1321
# Requisições restantes: (4865, 5000)
# Processados 53 stargazers. Números de nodes/edges 1183 1322
# Requisições restantes: (4864, 5000)
# Processados 54 stargazers. Números de nodes/edges 1183 1325
# Requisições restantes: (4863, 5000)
# Processados 55 stargazers. Números de nodes/edges 1183 1326
# Requisições restantes: (4862, 5000)
# Processados 56 stargazers. Números de nodes/edges 1183 1329
# Requisições restantes: (4860, 5000)
# Processados 57 stargazers. Números de nodes/edges 1183 1330
# Requisições restantes: (4859, 5000)
# Processados 58 stargazers. Números de nodes/edges 1183 1331
# Requisições restantes: (4858, 5000)
# Processados 59 stargazers. Números de nodes/edges 1183 1337
# Requisições restantes: (4855, 5000)
# Processados 60 stargazers. Números de nodes/edges 1183 1338
# Requisições restantes: (4854, 5000)
# Processados 61 stargazers. Números de nodes/edges 1183 1348
# Requisições restantes: (4847, 5000)
# Processados 62 stargazers. Números de nodes/edges 1183 1349
# Requisições restantes: (4846, 5000)
# Processados 63 stargazers. Números de nodes/edges 1183 1352
# Requisições restantes: (4845, 5000)
# Processados 64 stargazers. Números de nodes/edges 1183 1353
# Requisições restantes: (4844, 5000)
# Processados 65 stargazers. Números de nodes/edges 1183 1354
# Requisições restantes: (4843, 5000)
# Processados 66 stargazers. Números de nodes/edges 1183 1355
# Requisições restantes: (4842, 5000)
# Processados 67 stargazers. Números de nodes/edges 1183 1356
# Requisições restantes: (4841, 5000)
# Processados 68 stargazers. Números de nodes/edges 1183 1358
# Requisições restantes: (4839, 5000)
# Processados 69 stargazers. Números de nodes/edges 1183 1359
# Requisições restantes: (4838, 5000)
# Processados 70 stargazers. Números de nodes/edges 1183 1361
# Requisições restantes: (4837, 5000)
# Processados 71 stargazers. Números de nodes/edges 1183 1366
# Requisições restantes: (4835, 5000)
# Processados 72 stargazers. Números de nodes/edges 1183 1368
# Requisições restantes: (4834, 5000)
# Processados 73 stargazers. Números de nodes/edges 1183 1370
# Requisições restantes: (4833, 5000)
# Processados 74 stargazers. Números de nodes/edges 1183 1373
# Requisições restantes: (4831, 5000)
# Processados 75 stargazers. Números de nodes/edges 1183 1375
# Requisições restantes: (4829, 5000)
# Processados 76 stargazers. Números de nodes/edges 1183 1381
# Requisições restantes: (4826, 5000)
# Processados 77 stargazers. Números de nodes/edges 1183 1385
# Requisições restantes: (4824, 5000)
# Processados 78 stargazers. Números de nodes/edges 1183 1386
# Requisições restantes: (4823, 5000)
# Processados 79 stargazers. Números de nodes/edges 1183 1387
# Requisições restantes: (4822, 5000)
# Processados 80 stargazers. Números de nodes/edges 1183 1388
# Requisições restantes: (4821, 5000)
# Processados 81 stargazers. Números de nodes/edges 1183 1390
# Requisições restantes: (4820, 5000)
# Processados 82 stargazers. Números de nodes/edges 1183 1392
# Requisições restantes: (4819, 5000)
# Processados 83 stargazers. Números de nodes/edges 1183 1400
# Requisições restantes: (4816, 5000)
# Processados 84 stargazers. Números de nodes/edges 1183 1402
# Requisições restantes: (4815, 5000)
# Processados 85 stargazers. Números de nodes/edges 1183 1403
# Requisições restantes: (4814, 5000)
# Processados 86 stargazers. Números de nodes/edges 1183 1408
# Requisições restantes: (4811, 5000)
# Processados 87 stargazers. Números de nodes/edges 1183 1411
# Requisições restantes: (4810, 5000)
# Processados 88 stargazers. Números de nodes/edges 1183 1413
# Requisições restantes: (4809, 5000)
# Processados 89 stargazers. Números de nodes/edges 1183 1414
# Requisições restantes: (4808, 5000)
# Processados 90 stargazers. Números de nodes/edges 1183 1419
# Requisições restantes: (4806, 5000)
# Processados 91 stargazers. Números de nodes/edges 1183 1419
# Requisições restantes: (4805, 5000)
# Processados 92 stargazers. Números de nodes/edges 1183 1423
# Requisições restantes: (4804, 5000)
# Processados 93 stargazers. Números de nodes/edges 1183 1424
# Requisições restantes: (4803, 5000)
# Processados 94 stargazers. Números de nodes/edges 1183 1425
# Requisições restantes: (4802, 5000)
# Processados 95 stargazers. Números de nodes/edges 1183 1429
# Requisições restantes: (4800, 5000)
# Processados 96 stargazers. Números de nodes/edges 1183 1430
# Requisições restantes: (4799, 5000)
# Processados 97 stargazers. Números de nodes/edges 1183 1431
# Requisições restantes: (4798, 5000)
# Processados 98 stargazers. Números de nodes/edges 1183 1436
# Requisições restantes: (4793, 5000)
# Processados 99 stargazers. Números de nodes/edges 1183 1439
# Requisições restantes: (4792, 5000)
# Processados 100 stargazers. Números de nodes/edges 1183 1440
# Requisições restantes: (4791, 5000)
# Processados 101 stargazers. Números de nodes/edges 1183 1444
# Requisições restantes: (4788, 5000)
# Processados 102 stargazers. Números de nodes/edges 1183 1445
# Requisições restantes: (4787, 5000)
# Processados 103 stargazers. Números de nodes/edges 1183 1446
# Requisições restantes: (4786, 5000)
# Processados 104 stargazers. Números de nodes/edges 1183 1449
# Requisições restantes: (4785, 5000)
# Processados 105 stargazers. Números de nodes/edges 1183 1450
# Requisições restantes: (4784, 5000)
# Processados 106 stargazers. Números de nodes/edges 1183 1451
# Requisições restantes: (4783, 5000)
# Processados 107 stargazers. Números de nodes/edges 1183 1452
# Requisições restantes: (4782, 5000)
# Processados 108 stargazers. Números de nodes/edges 1183 1453
# Requisições restantes: (4781, 5000)
# Processados 109 stargazers. Números de nodes/edges 1183 1454
# Requisições restantes: (4780, 5000)
# Processados 110 stargazers. Números de nodes/edges 1183 1455
# Requisições restantes: (4779, 5000)
# Processados 111 stargazers. Números de nodes/edges 1183 1458
# Requisições restantes: (4778, 5000)
# Processados 112 stargazers. Números de nodes/edges 1183 1460
# Requisições restantes: (4777, 5000)
# Processados 113 stargazers. Números de nodes/edges 1183 1464
# Requisições restantes: (4775, 5000)
# Processados 114 stargazers. Números de nodes/edges 1183 1465
# Requisições restantes: (4774, 5000)
# Processados 115 stargazers. Números de nodes/edges 1183 1473
# Requisições restantes: (4773, 5000)
# Processados 116 stargazers. Números de nodes/edges 1183 1474
# Requisições restantes: (4772, 5000)
# Processados 117 stargazers. Números de nodes/edges 1183 1475
# Requisições restantes: (4771, 5000)
# Processados 118 stargazers. Números de nodes/edges 1183 1476
# Requisições restantes: (4770, 5000)
# Processados 119 stargazers. Números de nodes/edges 1183 1482
# Requisições restantes: (4768, 5000)
# Processados 120 stargazers. Números de nodes/edges 1183 1485
# Requisições restantes: (4764, 5000)
# Processados 121 stargazers. Números de nodes/edges 1183 1488
# Requisições restantes: (4763, 5000)
# Processados 122 stargazers. Números de nodes/edges 1183 1489
# Requisições restantes: (4762, 5000)
# Processados 123 stargazers. Números de nodes/edges 1183 1490
# Requisições restantes: (4761, 5000)
# Processados 124 stargazers. Números de nodes/edges 1183 1491
# Requisições restantes: (4760, 5000)
# Processados 125 stargazers. Números de nodes/edges 1183 1492
# Requisições restantes: (4759, 5000)
# Processados 126 stargazers. Números de nodes/edges 1183 1493
# Requisições restantes: (4758, 5000)
# Processados 127 stargazers. Números de nodes/edges 1183 1494
# Requisições restantes: (4757, 5000)
# Processados 128 stargazers. Números de nodes/edges 1183 1494
# Requisições restantes: (4756, 5000)
# Processados 129 stargazers. Números de nodes/edges 1183 1496
# Requisições restantes: (4755, 5000)
# Processados 130 stargazers. Números de nodes/edges 1183 1496
# Requisições restantes: (4754, 5000)
# Processados 131 stargazers. Números de nodes/edges 1183 1498
# Requisições restantes: (4753, 5000)
# Processados 132 stargazers. Números de nodes/edges 1183 1498
# Requisições restantes: (4752, 5000)
# Processados 133 stargazers. Números de nodes/edges 1183 1499
# Requisições restantes: (4751, 5000)
# Processados 134 stargazers. Números de nodes/edges 1183 1500
# Requisições restantes: (4750, 5000)
# Processados 135 stargazers. Números de nodes/edges 1183 1501
# Requisições restantes: (4749, 5000)
# Processados 136 stargazers. Números de nodes/edges 1183 1505
# Requisições restantes: (4737, 5000)
# Processados 137 stargazers. Números de nodes/edges 1183 1506
# Requisições restantes: (4736, 5000)
# Processados 138 stargazers. Números de nodes/edges 1183 1506
# Requisições restantes: (4735, 5000)
# Processados 139 stargazers. Números de nodes/edges 1183 1507
# Requisições restantes: (4734, 5000)
# Processados 140 stargazers. Números de nodes/edges 1183 1511
# Requisições restantes: (4732, 5000)
# Processados 141 stargazers. Números de nodes/edges 1183 1511
# Requisições restantes: (4731, 5000)
# Processados 142 stargazers. Números de nodes/edges 1183 1514
# Requisições restantes: (4730, 5000)
# Processados 143 stargazers. Números de nodes/edges 1183 1514
# Requisições restantes: (4729, 5000)
# Processados 144 stargazers. Números de nodes/edges 1183 1514
# Requisições restantes: (4728, 5000)
# Processados 145 stargazers. Números de nodes/edges 1183 1514
# Requisições restantes: (4727, 5000)
# Processados 146 stargazers. Números de nodes/edges 1183 1515
# Requisições restantes: (4726, 5000)
# Processados 147 stargazers. Números de nodes/edges 1183 1520
# Requisições restantes: (4722, 5000)
# Processados 148 stargazers. Números de nodes/edges 1183 1522
# Requisições restantes: (4721, 5000)
# Processados 149 stargazers. Números de nodes/edges 1183 1524
# Requisições restantes: (4720, 5000)
# Processados 150 stargazers. Números de nodes/edges 1183 1653
# Requisições restantes: (4711, 5000)
# Processados 151 stargazers. Números de nodes/edges 1183 1655
# Requisições restantes: (4709, 5000)
# Processados 152 stargazers. Números de nodes/edges 1183 1656
# Requisições restantes: (4708, 5000)
# Processados 153 stargazers. Números de nodes/edges 1183 1657
# Requisições restantes: (4707, 5000)
# Processados 154 stargazers. Números de nodes/edges 1183 1660
# Requisições restantes: (4704, 5000)
# Processados 155 stargazers. Números de nodes/edges 1183 1660
# Requisições restantes: (4703, 5000)
# Processados 156 stargazers. Números de nodes/edges 1183 1660
# Requisições restantes: (4702, 5000)
# Processados 157 stargazers. Números de nodes/edges 1183 1660
# Requisições restantes: (4701, 5000)
# Processados 158 stargazers. Números de nodes/edges 1183 1662
# Requisições restantes: (4699, 5000)
# Processados 159 stargazers. Números de nodes/edges 1183 1664
# Requisições restantes: (4697, 5000)
# Processados 160 stargazers. Números de nodes/edges 1183 1665
# Requisições restantes: (4696, 5000)
# Processados 161 stargazers. Números de nodes/edges 1183 1665
# Requisições restantes: (4695, 5000)
# Processados 162 stargazers. Números de nodes/edges 1183 1665
# Requisições restantes: (4694, 5000)
# Processados 163 stargazers. Números de nodes/edges 1183 1668
# Requisições restantes: (4693, 5000)
# Processados 164 stargazers. Números de nodes/edges 1183 1671
# Requisições restantes: (4692, 5000)
# Processados 165 stargazers. Números de nodes/edges 1183 1672
# Requisições restantes: (4691, 5000)
# Processados 166 stargazers. Números de nodes/edges 1183 1672
# Requisições restantes: (4689, 5000)
# Processados 167 stargazers. Números de nodes/edges 1183 1672
# Requisições restantes: (4688, 5000)
# Processados 168 stargazers. Números de nodes/edges 1183 1675
# Requisições restantes: (4687, 5000)
# Processados 169 stargazers. Números de nodes/edges 1183 1847
# Requisições restantes: (4421, 5000)
# Processados 170 stargazers. Números de nodes/edges 1183 1847
# Requisições restantes: (4420, 5000)
# Processados 171 stargazers. Números de nodes/edges 1183 1848
# Requisições restantes: (4419, 5000)
# Processados 172 stargazers. Números de nodes/edges 1183 1850
# Requisições restantes: (4417, 5000)
# Processados 173 stargazers. Números de nodes/edges 1183 1851
# Requisições restantes: (4416, 5000)
# Processados 174 stargazers. Números de nodes/edges 1183 1854
# Requisições restantes: (4415, 5000)
# Processados 175 stargazers. Números de nodes/edges 1183 1854
# Requisições restantes: (4414, 5000)
# Processados 176 stargazers. Números de nodes/edges 1183 1854
# Requisições restantes: (4413, 5000)
# Processados 177 stargazers. Números de nodes/edges 1183 1856
# Requisições restantes: (4412, 5000)
# Processados 178 stargazers. Números de nodes/edges 1183 1858
# Requisições restantes: (4410, 5000)
# Processados 179 stargazers. Números de nodes/edges 1183 1861
# Requisições restantes: (4408, 5000)
# Processados 180 stargazers. Números de nodes/edges 1183 1861
# Requisições restantes: (4406, 5000)
# Processados 181 stargazers. Números de nodes/edges 1183 1869
# Requisições restantes: (4404, 5000)
# Processados 182 stargazers. Números de nodes/edges 1183 1878
# Requisições restantes: (4401, 5000)
# Processados 183 stargazers. Números de nodes/edges 1183 1878
# Requisições restantes: (4400, 5000)
# Processados 184 stargazers. Números de nodes/edges 1183 1879
# Requisições restantes: (4399, 5000)
# Processados 185 stargazers. Números de nodes/edges 1183 1884
# Requisições restantes: (4396, 5000)
# Processados 186 stargazers. Números de nodes/edges 1183 1884
# Requisições restantes: (4395, 5000)
# Processados 187 stargazers. Números de nodes/edges 1183 1884
# Requisições restantes: (4394, 5000)
# Processados 188 stargazers. Números de nodes/edges 1183 1884
# Requisições restantes: (4393, 5000)
# Processados 189 stargazers. Números de nodes/edges 1183 1885
# Requisições restantes: (4392, 5000)
# Processados 190 stargazers. Números de nodes/edges 1183 1892
# Requisições restantes: (4390, 5000)
# Processados 191 stargazers. Números de nodes/edges 1183 1893
# Requisições restantes: (4389, 5000)
# Processados 192 stargazers. Números de nodes/edges 1183 1893
# Requisições restantes: (4388, 5000)
# Processados 193 stargazers. Números de nodes/edges 1183 1894
# Requisições restantes: (4387, 5000)
# Processados 194 stargazers. Números de nodes/edges 1183 1894
# Requisições restantes: (4386, 5000)
# Processados 195 stargazers. Números de nodes/edges 1183 1894
# Requisições restantes: (4385, 5000)
# Processados 196 stargazers. Números de nodes/edges 1183 1895
# Requisições restantes: (4384, 5000)
# Processados 197 stargazers. Números de nodes/edges 1183 1896
# Requisições restantes: (4383, 5000)
# Processados 198 stargazers. Números de nodes/edges 1183 1896
# Requisições restantes: (4382, 5000)
# Processados 199 stargazers. Números de nodes/edges 1183 1897
# Requisições restantes: (4381, 5000)
# Processados 200 stargazers. Números de nodes/edges 1183 1898
# Requisições restantes: (4380, 5000)
# Processados 201 stargazers. Números de nodes/edges 1183 1902
# Requisições restantes: (4379, 5000)
# Processados 202 stargazers. Números de nodes/edges 1183 1902
# Requisições restantes: (4378, 5000)
# Processados 203 stargazers. Números de nodes/edges 1183 1903
# Requisições restantes: (4377, 5000)
# Processados 204 stargazers. Números de nodes/edges 1183 1904
# Requisições restantes: (4376, 5000)
# Processados 205 stargazers. Números de nodes/edges 1183 1905
# Requisições restantes: (4374, 5000)
# Processados 206 stargazers. Números de nodes/edges 1183 1906
# Requisições restantes: (4373, 5000)
# Processados 207 stargazers. Números de nodes/edges 1183 1907
# Requisições restantes: (4372, 5000)
# Processados 208 stargazers. Números de nodes/edges 1183 1907
# Requisições restantes: (4371, 5000)
# Processados 209 stargazers. Números de nodes/edges 1183 1907
# Requisições restantes: (4370, 5000)
# Processados 210 stargazers. Números de nodes/edges 1183 1908
# Requisições restantes: (4369, 5000)
# Processados 211 stargazers. Números de nodes/edges 1183 1909
# Requisições restantes: (4368, 5000)
# Processados 212 stargazers. Números de nodes/edges 1183 1916
# Requisições restantes: (4365, 5000)
# Processados 213 stargazers. Números de nodes/edges 1183 1918
# Requisições restantes: (4364, 5000)
# Processados 214 stargazers. Números de nodes/edges 1183 1919
# Requisições restantes: (4363, 5000)
# Processados 215 stargazers. Números de nodes/edges 1183 1921
# Requisições restantes: (4362, 5000)
# Processados 216 stargazers. Números de nodes/edges 1183 1923
# Requisições restantes: (4361, 5000)
# Processados 217 stargazers. Números de nodes/edges 1183 1923
# Requisições restantes: (4360, 5000)
# Processados 218 stargazers. Números de nodes/edges 1183 1923
# Requisições restantes: (4359, 5000)
# Processados 219 stargazers. Números de nodes/edges 1183 1924
# Requisições restantes: (4358, 5000)
# Processados 220 stargazers. Números de nodes/edges 1183 1925
# Requisições restantes: (4357, 5000)
# Processados 221 stargazers. Números de nodes/edges 1183 1926
# Requisições restantes: (4356, 5000)
# Processados 222 stargazers. Números de nodes/edges 1183 1926
# Requisições restantes: (4355, 5000)
# Processados 223 stargazers. Números de nodes/edges 1183 1928
# Requisições restantes: (4354, 5000)
# Processados 224 stargazers. Números de nodes/edges 1183 1931
# Requisições restantes: (4353, 5000)
# Processados 225 stargazers. Números de nodes/edges 1183 1931
# Requisições restantes: (4352, 5000)
# Processados 226 stargazers. Números de nodes/edges 1183 1931
# Requisições restantes: (4351, 5000)
# Processados 227 stargazers. Números de nodes/edges 1183 1936
# Requisições restantes: (4348, 5000)
# Processados 228 stargazers. Números de nodes/edges 1183 1936
# Requisições restantes: (4347, 5000)
# Processados 229 stargazers. Números de nodes/edges 1183 1938
# Requisições restantes: (4346, 5000)
# Processados 230 stargazers. Números de nodes/edges 1183 1940
# Requisições restantes: (4345, 5000)
# Processados 231 stargazers. Números de nodes/edges 1183 1940
# Requisições restantes: (4344, 5000)
# Processados 232 stargazers. Números de nodes/edges 1183 1940
# Requisições restantes: (4343, 5000)
# Processados 233 stargazers. Números de nodes/edges 1183 1941
# Requisições restantes: (4342, 5000)
# Processados 234 stargazers. Números de nodes/edges 1183 1946
# Requisições restantes: (4341, 5000)
# Processados 235 stargazers. Números de nodes/edges 1183 1948
# Requisições restantes: (4340, 5000)
# Processados 236 stargazers. Números de nodes/edges 1183 1950
# Requisições restantes: (4339, 5000)
# Processados 237 stargazers. Números de nodes/edges 1183 1951
# Requisições restantes: (4338, 5000)
# Processados 238 stargazers. Números de nodes/edges 1183 1952
# Requisições restantes: (4337, 5000)
# Processados 239 stargazers. Números de nodes/edges 1183 1952
# Requisições restantes: (4336, 5000)
# Processados 240 stargazers. Números de nodes/edges 1183 1953
# Requisições restantes: (4335, 5000)
# Processados 241 stargazers. Números de nodes/edges 1183 1954
# Requisições restantes: (4334, 5000)
# Processados 242 stargazers. Números de nodes/edges 1183 1954
# Requisições restantes: (4333, 5000)
# Processados 243 stargazers. Números de nodes/edges 1183 1955
# Requisições restantes: (4332, 5000)
# Processados 244 stargazers. Números de nodes/edges 1183 1955
# Requisições restantes: (4331, 5000)
# Processados 245 stargazers. Números de nodes/edges 1183 1956
# Requisições restantes: (4330, 5000)
# Processados 246 stargazers. Números de nodes/edges 1183 1960
# Requisições restantes: (4329, 5000)
# Processados 247 stargazers. Números de nodes/edges 1183 1961
# Requisições restantes: (4328, 5000)
# Processados 248 stargazers. Números de nodes/edges 1183 1962
# Requisições restantes: (4327, 5000)
# Processados 249 stargazers. Números de nodes/edges 1183 1964
# Requisições restantes: (4326, 5000)
# Processados 250 stargazers. Números de nodes/edges 1183 1964
# Requisições restantes: (4325, 5000)
# Processados 251 stargazers. Números de nodes/edges 1183 1967
# Requisições restantes: (4322, 5000)
# Processados 252 stargazers. Números de nodes/edges 1183 1968
# Requisições restantes: (4321, 5000)
# Processados 253 stargazers. Números de nodes/edges 1183 1986
# Requisições restantes: (4319, 5000)
# Processados 254 stargazers. Números de nodes/edges 1183 1988
# Requisições restantes: (4318, 5000)
# Processados 255 stargazers. Números de nodes/edges 1183 1989
# Requisições restantes: (4317, 5000)
# Processados 256 stargazers. Números de nodes/edges 1183 1989
# Requisições restantes: (4316, 5000)
# Processados 257 stargazers. Números de nodes/edges 1183 1990
# Requisições restantes: (4315, 5000)
# Processados 258 stargazers. Números de nodes/edges 1183 1990
# Requisições restantes: (4314, 5000)
# Processados 259 stargazers. Números de nodes/edges 1183 1991
# Requisições restantes: (4313, 5000)
# Processados 260 stargazers. Números de nodes/edges 1183 1992
# Requisições restantes: (4312, 5000)
# Processados 261 stargazers. Números de nodes/edges 1183 1993
# Requisições restantes: (4311, 5000)
# Processados 262 stargazers. Números de nodes/edges 1183 1993
# Requisições restantes: (4310, 5000)
# Processados 263 stargazers. Números de nodes/edges 1183 1993
# Requisições restantes: (4309, 5000)
# Processados 264 stargazers. Números de nodes/edges 1183 1995
# Requisições restantes: (4308, 5000)
# Processados 265 stargazers. Números de nodes/edges 1183 1995
# Requisições restantes: (4307, 5000)
# Processados 266 stargazers. Números de nodes/edges 1183 1996
# Requisições restantes: (4306, 5000)
# Processados 267 stargazers. Números de nodes/edges 1183 1996
# Requisições restantes: (4305, 5000)
# Processados 268 stargazers. Números de nodes/edges 1183 1996
# Requisições restantes: (4304, 5000)
# Processados 269 stargazers. Números de nodes/edges 1183 1997
# Requisições restantes: (4303, 5000)
# Processados 270 stargazers. Números de nodes/edges 1183 1997
# Requisições restantes: (4302, 5000)
# Processados 271 stargazers. Números de nodes/edges 1183 1997
# Requisições restantes: (4301, 5000)
# Processados 272 stargazers. Números de nodes/edges 1183 1998
# Requisições restantes: (4300, 5000)
# Processados 273 stargazers. Números de nodes/edges 1183 1999
# Requisições restantes: (4299, 5000)
# Processados 274 stargazers. Números de nodes/edges 1183 2000
# Requisições restantes: (4298, 5000)
# Processados 275 stargazers. Números de nodes/edges 1183 2000
# Requisições restantes: (4297, 5000)
# Processados 276 stargazers. Números de nodes/edges 1183 2000
# Requisições restantes: (4296, 5000)
# Processados 277 stargazers. Números de nodes/edges 1183 2001
# Requisições restantes: (4295, 5000)
# Processados 278 stargazers. Números de nodes/edges 1183 2002
# Requisições restantes: (4294, 5000)
# Processados 279 stargazers. Números de nodes/edges 1183 2005
# Requisições restantes: (4293, 5000)
# Processados 280 stargazers. Números de nodes/edges 1183 2005
# Requisições restantes: (4292, 5000)
# Processados 281 stargazers. Números de nodes/edges 1183 2006
# Requisições restantes: (4291, 5000)
# Processados 282 stargazers. Números de nodes/edges 1183 2007
# Requisições restantes: (4290, 5000)
# Processados 283 stargazers. Números de nodes/edges 1183 2007
# Requisições restantes: (4289, 5000)
# Processados 284 stargazers. Números de nodes/edges 1183 2007
# Requisições restantes: (4288, 5000)
# Processados 285 stargazers. Números de nodes/edges 1183 2013
# Requisições restantes: (4285, 5000)
# Processados 286 stargazers. Números de nodes/edges 1183 2017
# Requisições restantes: (4283, 5000)
# Processados 287 stargazers. Números de nodes/edges 1183 2017
# Requisições restantes: (4282, 5000)
# Processados 288 stargazers. Números de nodes/edges 1183 2018
# Requisições restantes: (4280, 5000)
# Processados 289 stargazers. Números de nodes/edges 1183 2018
# Requisições restantes: (4279, 5000)
# Processados 290 stargazers. Números de nodes/edges 1183 2018
# Requisições restantes: (4278, 5000)
# Processados 291 stargazers. Números de nodes/edges 1183 2018
# Requisições restantes: (4277, 5000)
# Processados 292 stargazers. Números de nodes/edges 1183 2018
# Requisições restantes: (4276, 5000)
# Processados 293 stargazers. Números de nodes/edges 1183 2020
# Requisições restantes: (4275, 5000)
# Processados 294 stargazers. Números de nodes/edges 1183 2020
# Requisições restantes: (4274, 5000)
# Processados 295 stargazers. Números de nodes/edges 1183 2021
# Requisições restantes: (4273, 5000)
# Processados 296 stargazers. Números de nodes/edges 1183 2021
# Requisições restantes: (4272, 5000)
# Processados 297 stargazers. Números de nodes/edges 1183 2022
# Requisições restantes: (4271, 5000)
# Processados 298 stargazers. Números de nodes/edges 1183 2022
# Requisições restantes: (4270, 5000)
# Processados 299 stargazers. Números de nodes/edges 1183 2023
# Requisições restantes: (4269, 5000)
# Processados 300 stargazers. Números de nodes/edges 1183 2024
# Requisições restantes: (4268, 5000)
# Processados 301 stargazers. Números de nodes/edges 1183 2025
# Requisições restantes: (4267, 5000)
# Processados 302 stargazers. Números de nodes/edges 1183 2025
# Requisições restantes: (4266, 5000)
# Processados 303 stargazers. Números de nodes/edges 1183 2025
# Requisições restantes: (4265, 5000)
# Processados 304 stargazers. Números de nodes/edges 1183 2029
# Requisições restantes: (4263, 5000)
# Processados 305 stargazers. Números de nodes/edges 1183 2029
# Requisições restantes: (4262, 5000)
# Processados 306 stargazers. Números de nodes/edges 1183 2029
# Requisições restantes: (4261, 5000)
# Processados 307 stargazers. Números de nodes/edges 1183 2029
# Requisições restantes: (4260, 5000)
# Processados 308 stargazers. Números de nodes/edges 1183 2031
# Requisições restantes: (4259, 5000)
# Processados 309 stargazers. Números de nodes/edges 1183 2031
# Requisições restantes: (4258, 5000)
# Processados 310 stargazers. Números de nodes/edges 1183 2031
# Requisições restantes: (4257, 5000)
# Processados 311 stargazers. Números de nodes/edges 1183 2034
# Requisições restantes: (4256, 5000)
# Processados 312 stargazers. Números de nodes/edges 1183 2034
# Requisições restantes: (4255, 5000)
# Processados 313 stargazers. Números de nodes/edges 1183 2037
# Requisições restantes: (4254, 5000)
# Processados 314 stargazers. Números de nodes/edges 1183 2037
# Requisições restantes: (4253, 5000)
# Processados 315 stargazers. Números de nodes/edges 1183 2038
# Requisições restantes: (4252, 5000)
# Processados 316 stargazers. Números de nodes/edges 1183 2043
# Requisições restantes: (4250, 5000)
# Processados 317 stargazers. Números de nodes/edges 1183 2047
# Requisições restantes: (4247, 5000)
# Processados 318 stargazers. Números de nodes/edges 1183 2048
# Requisições restantes: (4246, 5000)
# Processados 319 stargazers. Números de nodes/edges 1183 2069
# Requisições restantes: (4233, 5000)
# Processados 320 stargazers. Números de nodes/edges 1183 2071
# Requisições restantes: (4232, 5000)
# Processados 321 stargazers. Números de nodes/edges 1183 2071
# Requisições restantes: (4231, 5000)
# Processados 322 stargazers. Números de nodes/edges 1183 2071
# Requisições restantes: (4230, 5000)
# Processados 323 stargazers. Números de nodes/edges 1183 2071
# Requisições restantes: (4229, 5000)
# Processados 324 stargazers. Números de nodes/edges 1183 2075
# Requisições restantes: (4226, 5000)
# Processados 325 stargazers. Números de nodes/edges 1183 2075
# Requisições restantes: (4225, 5000)
# Processados 326 stargazers. Números de nodes/edges 1183 2075
# Requisições restantes: (4224, 5000)
# Processados 327 stargazers. Números de nodes/edges 1183 2075
# Requisições restantes: (4223, 5000)
# Processados 328 stargazers. Números de nodes/edges 1183 2075
# Requisições restantes: (4222, 5000)
# Processados 329 stargazers. Números de nodes/edges 1183 2075
# Requisições restantes: (4221, 5000)
# Processados 330 stargazers. Números de nodes/edges 1183 2075
# Requisições restantes: (4220, 5000)
# Processados 331 stargazers. Números de nodes/edges 1183 2076
# Requisições restantes: (4219, 5000)
# Processados 332 stargazers. Números de nodes/edges 1183 2076
# Requisições restantes: (4218, 5000)
# Processados 333 stargazers. Números de nodes/edges 1183 2077
# Requisições restantes: (4217, 5000)
# Processados 334 stargazers. Números de nodes/edges 1183 2077
# Requisições restantes: (4216, 5000)
# Processados 335 stargazers. Números de nodes/edges 1183 2077
# Requisições restantes: (4215, 5000)
# Processados 336 stargazers. Números de nodes/edges 1183 2077
# Requisições restantes: (4214, 5000)
# Processados 337 stargazers. Números de nodes/edges 1183 2077
# Requisições restantes: (4213, 5000)
# Processados 338 stargazers. Números de nodes/edges 1183 2077
# Requisições restantes: (4212, 5000)
# Processados 339 stargazers. Números de nodes/edges 1183 2077
# Requisições restantes: (4211, 5000)
# Processados 340 stargazers. Números de nodes/edges 1183 2086
# Requisições restantes: (4209, 5000)
# Processados 341 stargazers. Números de nodes/edges 1183 2092
# Requisições restantes: (4205, 5000)
# Processados 342 stargazers. Números de nodes/edges 1183 2092
# Requisições restantes: (4204, 5000)
# Processados 343 stargazers. Números de nodes/edges 1183 2093
# Requisições restantes: (4203, 5000)
# Processados 344 stargazers. Números de nodes/edges 1183 2094
# Requisições restantes: (4202, 5000)
# Processados 345 stargazers. Números de nodes/edges 1183 2096
# Requisições restantes: (4201, 5000)
# Processados 346 stargazers. Números de nodes/edges 1183 2096
# Requisições restantes: (4200, 5000)
# Processados 347 stargazers. Números de nodes/edges 1183 2096
# Requisições restantes: (4199, 5000)
# Processados 348 stargazers. Números de nodes/edges 1183 2096
# Requisições restantes: (4198, 5000)
# Processados 349 stargazers. Números de nodes/edges 1183 2096
# Requisições restantes: (4197, 5000)
# Processados 350 stargazers. Números de nodes/edges 1183 2100
# Requisições restantes: (4195, 5000)
# Processados 351 stargazers. Números de nodes/edges 1183 2101
# Requisições restantes: (4194, 5000)
# Processados 352 stargazers. Números de nodes/edges 1183 2101
# Requisições restantes: (4193, 5000)
# Processados 353 stargazers. Números de nodes/edges 1183 2103
# Requisições restantes: (4189, 5000)
# Processados 354 stargazers. Números de nodes/edges 1183 2103
# Requisições restantes: (4188, 5000)
# Processados 355 stargazers. Números de nodes/edges 1183 2104
# Requisições restantes: (4187, 5000)
# Processados 356 stargazers. Números de nodes/edges 1183 2107
# Requisições restantes: (4186, 5000)
# Processados 357 stargazers. Números de nodes/edges 1183 2107
# Requisições restantes: (4185, 5000)
# Processados 358 stargazers. Números de nodes/edges 1183 2107
# Requisições restantes: (4184, 5000)
# Processados 359 stargazers. Números de nodes/edges 1183 2108
# Requisições restantes: (4183, 5000)
# Processados 360 stargazers. Números de nodes/edges 1183 2110
# Requisições restantes: (4182, 5000)
# Processados 361 stargazers. Números de nodes/edges 1183 2110
# Requisições restantes: (4181, 5000)
# Processados 362 stargazers. Números de nodes/edges 1183 2111
# Requisições restantes: (4180, 5000)
# Processados 363 stargazers. Números de nodes/edges 1183 2112
# Requisições restantes: (4179, 5000)
# Processados 364 stargazers. Números de nodes/edges 1183 2115
# Requisições restantes: (4178, 5000)
# Processados 365 stargazers. Números de nodes/edges 1183 2116
# Requisições restantes: (4177, 5000)
# Processados 366 stargazers. Números de nodes/edges 1183 2116
# Requisições restantes: (4176, 5000)
# Processados 367 stargazers. Números de nodes/edges 1183 2119
# Requisições restantes: (4173, 5000)
# Processados 368 stargazers. Números de nodes/edges 1183 2119
# Requisições restantes: (4172, 5000)
# Processados 369 stargazers. Números de nodes/edges 1183 2120
# Requisições restantes: (4171, 5000)
# Processados 370 stargazers. Números de nodes/edges 1183 2121
# Requisições restantes: (4170, 5000)
# Processados 371 stargazers. Números de nodes/edges 1183 2123
# Requisições restantes: (4169, 5000)
# Processados 372 stargazers. Números de nodes/edges 1183 2124
# Requisições restantes: (4168, 5000)
# Processados 373 stargazers. Números de nodes/edges 1183 2124
# Requisições restantes: (4167, 5000)
# Processados 374 stargazers. Números de nodes/edges 1183 2125
# Requisições restantes: (4166, 5000)
# Processados 375 stargazers. Números de nodes/edges 1183 2125
# Requisições restantes: (4165, 5000)
# Processados 376 stargazers. Números de nodes/edges 1183 2126
# Requisições restantes: (4164, 5000)
# Processados 377 stargazers. Números de nodes/edges 1183 2126
# Requisições restantes: (4163, 5000)
# Processados 378 stargazers. Números de nodes/edges 1183 2126
# Requisições restantes: (4162, 5000)
# Processados 379 stargazers. Números de nodes/edges 1183 2127
# Requisições restantes: (4161, 5000)
# Processados 380 stargazers. Números de nodes/edges 1183 2127
# Requisições restantes: (4160, 5000)
# Processados 381 stargazers. Números de nodes/edges 1183 2132
# Requisições restantes: (4157, 5000)
# Processados 382 stargazers. Números de nodes/edges 1183 2132
# Requisições restantes: (4156, 5000)
# Processados 383 stargazers. Números de nodes/edges 1183 2132
# Requisições restantes: (4155, 5000)
# Processados 384 stargazers. Números de nodes/edges 1183 2132
# Requisições restantes: (4154, 5000)
# Processados 385 stargazers. Números de nodes/edges 1183 2133
# Requisições restantes: (4153, 5000)
# Processados 386 stargazers. Números de nodes/edges 1183 2133
# Requisições restantes: (4152, 5000)
# Processados 387 stargazers. Números de nodes/edges 1183 2134
# Requisições restantes: (4151, 5000)
# Processados 388 stargazers. Números de nodes/edges 1183 2137
# Requisições restantes: (4150, 5000)
# Processados 389 stargazers. Números de nodes/edges 1183 2140
# Requisições restantes: (4149, 5000)
# Processados 390 stargazers. Números de nodes/edges 1183 2140
# Requisições restantes: (4148, 5000)
# Processados 391 stargazers. Números de nodes/edges 1183 2142
# Requisições restantes: (4147, 5000)
# Processados 392 stargazers. Números de nodes/edges 1183 2142
# Requisições restantes: (4146, 5000)
# Processados 393 stargazers. Números de nodes/edges 1183 2142
# Requisições restantes: (4145, 5000)
# Processados 394 stargazers. Números de nodes/edges 1183 2142
# Requisições restantes: (4144, 5000)
# Processados 395 stargazers. Números de nodes/edges 1183 2146
# Requisições restantes: (4139, 5000)
# Processados 396 stargazers. Números de nodes/edges 1183 2146
# Requisições restantes: (4138, 5000)
# Processados 397 stargazers. Números de nodes/edges 1183 2147
# Requisições restantes: (4137, 5000)
# Processados 398 stargazers. Números de nodes/edges 1183 2148
# Requisições restantes: (4136, 5000)
# Processados 399 stargazers. Números de nodes/edges 1183 2148
# Requisições restantes: (4135, 5000)
# Processados 400 stargazers. Números de nodes/edges 1183 2148
# Requisições restantes: (4134, 5000)
# Processados 401 stargazers. Números de nodes/edges 1183 2148
# Requisições restantes: (4133, 5000)
# Processados 402 stargazers. Números de nodes/edges 1183 2148
# Requisições restantes: (4132, 5000)
# Processados 403 stargazers. Números de nodes/edges 1183 2149
# Requisições restantes: (4131, 5000)
# Processados 404 stargazers. Números de nodes/edges 1183 2150
# Requisições restantes: (4130, 5000)
# Processados 405 stargazers. Números de nodes/edges 1183 2150
# Requisições restantes: (4129, 5000)
# Processados 406 stargazers. Números de nodes/edges 1183 2151
# Requisições restantes: (4128, 5000)
# Processados 407 stargazers. Números de nodes/edges 1183 2151
# Requisições restantes: (4127, 5000)
# Processados 408 stargazers. Números de nodes/edges 1183 2151
# Requisições restantes: (4126, 5000)
# Processados 409 stargazers. Números de nodes/edges 1183 2152
# Requisições restantes: (4125, 5000)
# Processados 410 stargazers. Números de nodes/edges 1183 2152
# Requisições restantes: (4124, 5000)
# Processados 411 stargazers. Números de nodes/edges 1183 2152
# Requisições restantes: (4123, 5000)
# Processados 412 stargazers. Números de nodes/edges 1183 2152
# Requisições restantes: (4122, 5000)
# Processados 413 stargazers. Números de nodes/edges 1183 2153
# Requisições restantes: (4121, 5000)
# Processados 414 stargazers. Números de nodes/edges 1183 2153
# Requisições restantes: (4120, 5000)
# Processados 415 stargazers. Números de nodes/edges 1183 2153
# Requisições restantes: (4119, 5000)
# Processados 416 stargazers. Números de nodes/edges 1183 2153
# Requisições restantes: (4118, 5000)
# Processados 417 stargazers. Números de nodes/edges 1183 2154
# Requisições restantes: (4117, 5000)
# Processados 418 stargazers. Números de nodes/edges 1183 2157
# Requisições restantes: (4115, 5000)
# Processados 419 stargazers. Números de nodes/edges 1183 2159
# Requisições restantes: (4114, 5000)
# Processados 420 stargazers. Números de nodes/edges 1183 2159
# Requisições restantes: (4113, 5000)
# Processados 421 stargazers. Números de nodes/edges 1183 2159
# Requisições restantes: (4112, 5000)
# Processados 422 stargazers. Números de nodes/edges 1183 2159
# Requisições restantes: (4111, 5000)
# Processados 423 stargazers. Números de nodes/edges 1183 2161
# Requisições restantes: (4110, 5000)
# Processados 424 stargazers. Números de nodes/edges 1183 2163
# Requisições restantes: (4107, 5000)
# Processados 425 stargazers. Números de nodes/edges 1183 2163
# Requisições restantes: (4106, 5000)
# Processados 426 stargazers. Números de nodes/edges 1183 2164
# Requisições restantes: (4105, 5000)
# Processados 427 stargazers. Números de nodes/edges 1183 2165
# Requisições restantes: (4104, 5000)
# Processados 428 stargazers. Números de nodes/edges 1183 2167
# Requisições restantes: (4103, 5000)
# Processados 429 stargazers. Números de nodes/edges 1183 2167
# Requisições restantes: (4102, 5000)
# Processados 430 stargazers. Números de nodes/edges 1183 2173
# Requisições restantes: (4099, 5000)
# Processados 431 stargazers. Números de nodes/edges 1183 2173
# Requisições restantes: (4098, 5000)
# Processados 432 stargazers. Números de nodes/edges 1183 2174
# Requisições restantes: (4097, 5000)
# Processados 433 stargazers. Números de nodes/edges 1183 2175
# Requisições restantes: (4096, 5000)
# Processados 434 stargazers. Números de nodes/edges 1183 2177
# Requisições restantes: (4095, 5000)
# Processados 435 stargazers. Números de nodes/edges 1183 2179
# Requisições restantes: (4094, 5000)
# Processados 436 stargazers. Números de nodes/edges 1183 2180
# Requisições restantes: (4093, 5000)
# Processados 437 stargazers. Números de nodes/edges 1183 2180
# Requisições restantes: (4092, 5000)
# Processados 438 stargazers. Números de nodes/edges 1183 2184
# Requisições restantes: (4087, 5000)
# Processados 439 stargazers. Números de nodes/edges 1183 2184
# Requisições restantes: (4086, 5000)
# Processados 440 stargazers. Números de nodes/edges 1183 2184
# Requisições restantes: (4085, 5000)
# Processados 441 stargazers. Números de nodes/edges 1183 2188
# Requisições restantes: (4082, 5000)
# Processados 442 stargazers. Números de nodes/edges 1183 2188
# Requisições restantes: (4081, 5000)
# Processados 443 stargazers. Números de nodes/edges 1183 2188
# Requisições restantes: (4080, 5000)
# Processados 444 stargazers. Números de nodes/edges 1183 2188
# Requisições restantes: (4079, 5000)
# Processados 445 stargazers. Números de nodes/edges 1183 2189
# Requisições restantes: (4078, 5000)
# Processados 446 stargazers. Números de nodes/edges 1183 2189
# Requisições restantes: (4077, 5000)
# Processados 447 stargazers. Números de nodes/edges 1183 2190
# Requisições restantes: (4076, 5000)
# Processados 448 stargazers. Números de nodes/edges 1183 2190
# Requisições restantes: (4075, 5000)
# Processados 449 stargazers. Números de nodes/edges 1183 2191
# Requisições restantes: (4074, 5000)
# Processados 450 stargazers. Números de nodes/edges 1183 2191
# Requisições restantes: (4073, 5000)
# Processados 451 stargazers. Números de nodes/edges 1183 2192
# Requisições restantes: (4072, 5000)
# Processados 452 stargazers. Números de nodes/edges 1183 2192
# Requisições restantes: (4071, 5000)
# Processados 453 stargazers. Números de nodes/edges 1183 2193
# Requisições restantes: (4070, 5000)
# Processados 454 stargazers. Números de nodes/edges 1183 2194
# Requisições restantes: (4069, 5000)
# Processados 455 stargazers. Números de nodes/edges 1183 2194
# Requisições restantes: (4068, 5000)
# Processados 456 stargazers. Números de nodes/edges 1183 2196
# Requisições restantes: (4067, 5000)
# Processados 457 stargazers. Números de nodes/edges 1183 2196
# Requisições restantes: (4066, 5000)
# Processados 458 stargazers. Números de nodes/edges 1183 2200
# Requisições restantes: (4064, 5000)
# Processados 459 stargazers. Números de nodes/edges 1183 2200
# Requisições restantes: (4063, 5000)
# Processados 460 stargazers. Números de nodes/edges 1183 2200
# Requisições restantes: (4062, 5000)
# Processados 461 stargazers. Números de nodes/edges 1183 2200
# Requisições restantes: (4061, 5000)
# Processados 462 stargazers. Números de nodes/edges 1183 2203
# Requisições restantes: (4060, 5000)
# Processados 463 stargazers. Números de nodes/edges 1183 2203
# Requisições restantes: (4059, 5000)
# Processados 464 stargazers. Números de nodes/edges 1183 2203
# Requisições restantes: (4058, 5000)
# Processados 465 stargazers. Números de nodes/edges 1183 2203
# Requisições restantes: (4057, 5000)
# Processados 466 stargazers. Números de nodes/edges 1183 2205
# Requisições restantes: (4056, 5000)
# Processados 467 stargazers. Números de nodes/edges 1183 2206
# Requisições restantes: (4055, 5000)
# Processados 468 stargazers. Números de nodes/edges 1183 2206
# Requisições restantes: (4054, 5000)
# Processados 469 stargazers. Números de nodes/edges 1183 2207
# Requisições restantes: (4053, 5000)
# Processados 470 stargazers. Números de nodes/edges 1183 2208
# Requisições restantes: (4052, 5000)
# Processados 471 stargazers. Números de nodes/edges 1183 2208
# Requisições restantes: (4051, 5000)
# Processados 472 stargazers. Números de nodes/edges 1183 2209
# Requisições restantes: (4050, 5000)
# Processados 473 stargazers. Números de nodes/edges 1183 2211
# Requisições restantes: (4049, 5000)
# Processados 474 stargazers. Números de nodes/edges 1183 2212
# Requisições restantes: (4048, 5000)
# Processados 475 stargazers. Números de nodes/edges 1183 2212
# Requisições restantes: (4047, 5000)
# Processados 476 stargazers. Números de nodes/edges 1183 2217
# Requisições restantes: (4045, 5000)
# Processados 477 stargazers. Números de nodes/edges 1183 2218
# Requisições restantes: (4044, 5000)
# Processados 478 stargazers. Números de nodes/edges 1183 2218
# Requisições restantes: (4043, 5000)
# Processados 479 stargazers. Números de nodes/edges 1183 2218
# Requisições restantes: (4042, 5000)
# Processados 480 stargazers. Números de nodes/edges 1183 2218
# Requisições restantes: (4041, 5000)
# Processados 481 stargazers. Números de nodes/edges 1183 2218
# Requisições restantes: (4040, 5000)
# Processados 482 stargazers. Números de nodes/edges 1183 2218
# Requisições restantes: (4039, 5000)
# Processados 483 stargazers. Números de nodes/edges 1183 2218
# Requisições restantes: (4038, 5000)
# Processados 484 stargazers. Números de nodes/edges 1183 2218
# Requisições restantes: (4037, 5000)
# Processados 485 stargazers. Números de nodes/edges 1183 2219
# Requisições restantes: (4036, 5000)
# Processados 486 stargazers. Números de nodes/edges 1183 2219
# Requisições restantes: (4035, 5000)
# Processados 487 stargazers. Números de nodes/edges 1183 2219
# Requisições restantes: (4034, 5000)
# Processados 488 stargazers. Números de nodes/edges 1183 2219
# Requisições restantes: (4033, 5000)
# Processados 489 stargazers. Números de nodes/edges 1183 2219
# Requisições restantes: (4032, 5000)
# Processados 490 stargazers. Números de nodes/edges 1183 2219
# Requisições restantes: (4031, 5000)
# Processados 491 stargazers. Números de nodes/edges 1183 2219
# Requisições restantes: (4030, 5000)
# Processados 492 stargazers. Números de nodes/edges 1183 2223
# Requisições restantes: (4029, 5000)
# Processados 493 stargazers. Números de nodes/edges 1183 2223
# Requisições restantes: (4028, 5000)
# Processados 494 stargazers. Números de nodes/edges 1183 2223
# Requisições restantes: (4027, 5000)
# Processados 495 stargazers. Números de nodes/edges 1183 2223
# Requisições restantes: (4026, 5000)
# Processados 496 stargazers. Números de nodes/edges 1183 2223
# ...
# Processados 1020 stargazers. Números de nodes/edges 1183 2767
# Requisições restantes: (3000, 5000)
# Processados 1021 stargazers. Números de nodes/edges 1183 2767
# Requisições restantes: (2999, 5000)
# Processados 1022 stargazers. Números de nodes/edges 1183 2767
# Requisições restantes: (2998, 5000)
# Processados 1023 stargazers. Números de nodes/edges 1183 2767
# Requisições restantes: (2997, 5000)
# Processados 1024 stargazers. Números de nodes/edges 1183 2769
# Requisições restantes: (2996, 5000)
# Processados 1025 stargazers. Números de nodes/edges 1183 2773
# Requisições restantes: (2994, 5000)
# Processados 1026 stargazers. Números de nodes/edges 1183 2774
# Requisições restantes: (2993, 5000)
# Processados 1027 stargazers. Números de nodes/edges 1183 2775
# Requisições restantes: (2991, 5000)
# Processados 1028 stargazers. Números de nodes/edges 1183 2775
# Requisições restantes: (2990, 5000)
# Processados 1029 stargazers. Números de nodes/edges 1183 2775
# Requisições restantes: (2989, 5000)
# Processados 1030 stargazers. Números de nodes/edges 1183 2776
# Requisições restantes: (2988, 5000)
# Processados 1031 stargazers. Números de nodes/edges 1183 2776
# Requisições restantes: (2987, 5000)
# Processados 1032 stargazers. Números de nodes/edges 1183 2776
# Requisições restantes: (2986, 5000)
# Processados 1033 stargazers. Números de nodes/edges 1183 2779
# Requisições restantes: (2985, 5000)
# Processados 1034 stargazers. Números de nodes/edges 1183 2779
# Requisições restantes: (2984, 5000)
# Processados 1035 stargazers. Números de nodes/edges 1183 2779
# Requisições restantes: (2983, 5000)
# Processados 1036 stargazers. Números de nodes/edges 1183 2779
# Requisições restantes: (2982, 5000)
# Processados 1037 stargazers. Números de nodes/edges 1183 2779
# Requisições restantes: (2981, 5000)
# Processados 1038 stargazers. Números de nodes/edges 1183 2779
# Requisições restantes: (2980, 5000)
# Processados 1039 stargazers. Números de nodes/edges 1183 2779
# Requisições restantes: (2979, 5000)
# Processados 1040 stargazers. Números de nodes/edges 1183 2779
# Requisições restantes: (2978, 5000)
# Processados 1041 stargazers. Números de nodes/edges 1183 2779
# Requisições restantes: (2977, 5000)
# Processados 1042 stargazers. Números de nodes/edges 1183 2780
# Requisições restantes: (2976, 5000)
# Processados 1043 stargazers. Números de nodes/edges 1183 2783
# Requisições restantes: (2974, 5000)
# Processados 1044 stargazers. Números de nodes/edges 1183 2784
# Requisições restantes: (2973, 5000)
# Processados 1045 stargazers. Números de nodes/edges 1183 2784
# Requisições restantes: (2972, 5000)
# Processados 1046 stargazers. Números de nodes/edges 1183 2784
# Requisições restantes: (2971, 5000)
# Processados 1047 stargazers. Números de nodes/edges 1183 2784
# Requisições restantes: (2970, 5000)
# Processados 1048 stargazers. Números de nodes/edges 1183 2784
# Requisições restantes: (2969, 5000)
# Processados 1049 stargazers. Números de nodes/edges 1183 2784
# Requisições restantes: (2968, 5000)
# Processados 1050 stargazers. Números de nodes/edges 1183 2785
# Requisições restantes: (2967, 5000)
# Processados 1051 stargazers. Números de nodes/edges 1183 2785
# Requisições restantes: (2966, 5000)
# Processados 1052 stargazers. Números de nodes/edges 1183 2786
# Requisições restantes: (2965, 5000)
# Processados 1053 stargazers. Números de nodes/edges 1183 2787
# Requisições restantes: (2964, 5000)
# Processados 1054 stargazers. Números de nodes/edges 1183 2787
# Requisições restantes: (2963, 5000)
# Processados 1055 stargazers. Números de nodes/edges 1183 2787
# Requisições restantes: (2962, 5000)
# Processados 1056 stargazers. Números de nodes/edges 1183 2787
# Requisições restantes: (2961, 5000)
# Processados 1057 stargazers. Números de nodes/edges 1183 2788
# Requisições restantes: (2960, 5000)
# Processados 1058 stargazers. Números de nodes/edges 1183 2788
# Requisições restantes: (2959, 5000)
# Processados 1059 stargazers. Números de nodes/edges 1183 2788
# Requisições restantes: (2958, 5000)
# Processados 1060 stargazers. Números de nodes/edges 1183 2788
# Requisições restantes: (2957, 5000)
# Processados 1061 stargazers. Números de nodes/edges 1183 2788
# Requisições restantes: (2956, 5000)
# Processados 1062 stargazers. Números de nodes/edges 1183 2788
# Requisições restantes: (2955, 5000)
# Processados 1063 stargazers. Números de nodes/edges 1183 2789
# Requisições restantes: (2954, 5000)
# Processados 1064 stargazers. Números de nodes/edges 1183 2790
# Requisições restantes: (2953, 5000)
# Processados 1065 stargazers. Números de nodes/edges 1183 2790
# Requisições restantes: (2952, 5000)
# Processados 1066 stargazers. Números de nodes/edges 1183 2790
# Requisições restantes: (2951, 5000)
# Processados 1067 stargazers. Números de nodes/edges 1183 2790
# Requisições restantes: (2950, 5000)
# Processados 1068 stargazers. Números de nodes/edges 1183 2790
# Requisições restantes: (2949, 5000)
# Processados 1069 stargazers. Números de nodes/edges 1183 2790
# Requisições restantes: (2948, 5000)
# Processados 1070 stargazers. Números de nodes/edges 1183 2791
# Requisições restantes: (2947, 5000)
# Processados 1071 stargazers. Números de nodes/edges 1183 2795
# Requisições restantes: (2946, 5000)
# Processados 1072 stargazers. Números de nodes/edges 1183 2795
# Requisições restantes: (2945, 5000)
# Processados 1073 stargazers. Números de nodes/edges 1183 2795
# Requisições restantes: (2944, 5000)
# Processados 1074 stargazers. Números de nodes/edges 1183 2795
# Requisições restantes: (2943, 5000)
# Processados 1075 stargazers. Números de nodes/edges 1183 2795
# Requisições restantes: (2942, 5000)
# Processados 1076 stargazers. Números de nodes/edges 1183 2795
# Requisições restantes: (2941, 5000)
# Processados 1077 stargazers. Números de nodes/edges 1183 2795
# Requisições restantes: (2940, 5000)
# Processados 1078 stargazers. Números de nodes/edges 1183 2795
# Requisições restantes: (2939, 5000)
# Processados 1079 stargazers. Números de nodes/edges 1183 2796
# Requisições restantes: (2937, 5000)
# Processados 1080 stargazers. Números de nodes/edges 1183 2796
# Requisições restantes: (2936, 5000)
# Processados 1081 stargazers. Números de nodes/edges 1183 2796
# Requisições restantes: (2935, 5000)
# Processados 1082 stargazers. Números de nodes/edges 1183 2796
# Requisições restantes: (2934, 5000)
# Processados 1083 stargazers. Números de nodes/edges 1183 2796
# Requisições restantes: (2933, 5000)
# Processados 1084 stargazers. Números de nodes/edges 1183 2797
# Requisições restantes: (2932, 5000)
# Processados 1085 stargazers. Números de nodes/edges 1183 2797
# Requisições restantes: (2931, 5000)
# Processados 1086 stargazers. Números de nodes/edges 1183 2797
# Requisições restantes: (2930, 5000)
# Processados 1087 stargazers. Números de nodes/edges 1183 2797
# Requisições restantes: (2929, 5000)
# Processados 1088 stargazers. Números de nodes/edges 1183 2797
# Requisições restantes: (2928, 5000)
# Processados 1089 stargazers. Números de nodes/edges 1183 2798
# Requisições restantes: (2926, 5000)
# Processados 1090 stargazers. Números de nodes/edges 1183 2798
# Requisições restantes: (2925, 5000)
# Processados 1091 stargazers. Números de nodes/edges 1183 2800
# Requisições restantes: (2923, 5000)
# Processados 1092 stargazers. Números de nodes/edges 1183 2800
# Requisições restantes: (2922, 5000)
# Processados 1093 stargazers. Números de nodes/edges 1183 2800
# Requisições restantes: (2921, 5000)
# Processados 1094 stargazers. Números de nodes/edges 1183 2800
# Requisições restantes: (2920, 5000)
# Processados 1095 stargazers. Números de nodes/edges 1183 2802
# Requisições restantes: (2919, 5000)
# Processados 1096 stargazers. Números de nodes/edges 1183 2802
# Requisições restantes: (2918, 5000)
# Processados 1097 stargazers. Números de nodes/edges 1183 2802
# Requisições restantes: (2917, 5000)
# Processados 1098 stargazers. Números de nodes/edges 1183 2802
# Requisições restantes: (2916, 5000)
# Processados 1099 stargazers. Números de nodes/edges 1183 2804
# Requisições restantes: (2914, 5000)
# Processados 1100 stargazers. Números de nodes/edges 1183 2804
# Requisições restantes: (2913, 5000)
# Processados 1101 stargazers. Números de nodes/edges 1183 2804
# Requisições restantes: (2912, 5000)
# Processados 1102 stargazers. Números de nodes/edges 1183 2804
# Requisições restantes: (2911, 5000)
# Processados 1103 stargazers. Números de nodes/edges 1183 2804
# Requisições restantes: (2910, 5000)
# Processados 1104 stargazers. Números de nodes/edges 1183 2807
# Requisições restantes: (2909, 5000)
# Processados 1105 stargazers. Números de nodes/edges 1183 2808
# Requisições restantes: (2907, 5000)
# Processados 1106 stargazers. Números de nodes/edges 1183 2809
# Requisições restantes: (2906, 5000)
# Processados 1107 stargazers. Números de nodes/edges 1183 2809
# Requisições restantes: (2905, 5000)
# Processados 1108 stargazers. Números de nodes/edges 1183 2810
# Requisições restantes: (2904, 5000)
# Processados 1109 stargazers. Números de nodes/edges 1183 2810
# Requisições restantes: (2903, 5000)
# Processados 1110 stargazers. Números de nodes/edges 1183 2810
# Requisições restantes: (2902, 5000)
# Processados 1111 stargazers. Números de nodes/edges 1183 2817
# Requisições restantes: (2895, 5000)
# Processados 1112 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2894, 5000)
# Processados 1113 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2893, 5000)
# Processados 1114 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2892, 5000)
# Processados 1115 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2891, 5000)
# Processados 1116 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2888, 5000)
# Processados 1117 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2887, 5000)
# Processados 1118 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2886, 5000)
# Processados 1119 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2885, 5000)
# Processados 1120 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2884, 5000)
# Processados 1121 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2883, 5000)
# Processados 1122 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2882, 5000)
# Processados 1123 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2881, 5000)
# Processados 1124 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2880, 5000)
# Processados 1125 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2879, 5000)
# Processados 1126 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2878, 5000)
# Processados 1127 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2877, 5000)
# Processados 1128 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2876, 5000)
# Processados 1129 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2875, 5000)
# Processados 1130 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2874, 5000)
# Processados 1131 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2873, 5000)
# Processados 1132 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2872, 5000)
# Processados 1133 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2871, 5000)
# Processados 1134 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2870, 5000)
# Processados 1135 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2869, 5000)
# Processados 1136 stargazers. Números de nodes/edges 1183 2818
# Requisições restantes: (2868, 5000)
# Processados 1137 stargazers. Números de nodes/edges 1183 2819
# Requisições restantes: (2867, 5000)
# Processados 1138 stargazers. Números de nodes/edges 1183 2819
# Requisições restantes: (2866, 5000)
# Processados 1139 stargazers. Números de nodes/edges 1183 2819
# Requisições restantes: (2865, 5000)
# Processados 1140 stargazers. Números de nodes/edges 1183 2819
# Requisições restantes: (2864, 5000)
# Processados 1141 stargazers. Números de nodes/edges 1183 2819
# Requisições restantes: (2863, 5000)
# Processados 1142 stargazers. Números de nodes/edges 1183 2820
# Requisições restantes: (2862, 5000)
# Processados 1143 stargazers. Números de nodes/edges 1183 2820
# Requisições restantes: (2861, 5000)
# Processados 1144 stargazers. Números de nodes/edges 1183 2820
# Requisições restantes: (2860, 5000)
# Processados 1145 stargazers. Números de nodes/edges 1183 2820
# Requisições restantes: (2859, 5000)
# Processados 1146 stargazers. Números de nodes/edges 1183 2820
# Requisições restantes: (2858, 5000)
# Processados 1147 stargazers. Números de nodes/edges 1183 2820
# Requisições restantes: (2857, 5000)
# Processados 1148 stargazers. Números de nodes/edges 1183 2820
# Requisições restantes: (2856, 5000)
# Processados 1149 stargazers. Números de nodes/edges 1183 2820
# Requisições restantes: (2855, 5000)
# Processados 1150 stargazers. Números de nodes/edges 1183 2820
# Requisições restantes: (2854, 5000)
# Processados 1151 stargazers. Números de nodes/edges 1183 2820
# Requisições restantes: (2853, 5000)
# Processados 1152 stargazers. Números de nodes/edges 1183 2820
# Requisições restantes: (2852, 5000)
# Processados 1153 stargazers. Números de nodes/edges 1183 2820
# Requisições restantes: (2851, 5000)
# Processados 1154 stargazers. Números de nodes/edges 1183 2820
# Requisições restantes: (2850, 5000)
# Processados 1155 stargazers. Números de nodes/edges 1183 2822
# Requisições restantes: (2849, 5000)
# Processados 1156 stargazers. Números de nodes/edges 1183 2823
# Requisições restantes: (2848, 5000)
# Processados 1157 stargazers. Números de nodes/edges 1183 2823
# Requisições restantes: (2847, 5000)
# Processados 1158 stargazers. Números de nodes/edges 1183 2823
# Requisições restantes: (2846, 5000)
# Processados 1159 stargazers. Números de nodes/edges 1183 2823
# Requisições restantes: (2845, 5000)
# Processados 1160 stargazers. Números de nodes/edges 1183 2823
# Requisições restantes: (2844, 5000)
# Processados 1161 stargazers. Números de nodes/edges 1183 2823
# Requisições restantes: (2843, 5000)
# Processados 1162 stargazers. Números de nodes/edges 1183 2823
# Requisições restantes: (2842, 5000)
# Processados 1163 stargazers. Números de nodes/edges 1183 2823
# Requisições restantes: (2841, 5000)
# Processados 1164 stargazers. Números de nodes/edges 1183 2823
# Requisições restantes: (2840, 5000)
# Processados 1165 stargazers. Números de nodes/edges 1183 2823
# Requisições restantes: (2839, 5000)
# Processados 1166 stargazers. Números de nodes/edges 1183 2823
# Requisições restantes: (2838, 5000)
# Processados 1167 stargazers. Números de nodes/edges 1183 2823
# Requisições restantes: (2837, 5000)
# Processados 1168 stargazers. Números de nodes/edges 1183 2823
# Requisições restantes: (2836, 5000)
# Processados 1169 stargazers. Números de nodes/edges 1183 2823
# Requisições restantes: (2835, 5000)
# Processados 1170 stargazers. Números de nodes/edges 1183 2823
# Requisições restantes: (2834, 5000)
# Processados 1171 stargazers. Números de nodes/edges 1183 2824
# Requisições restantes: (2833, 5000)
# Processados 1172 stargazers. Números de nodes/edges 1183 2824
# Requisições restantes: (2832, 5000)
# Processados 1173 stargazers. Números de nodes/edges 1183 2824
# Requisições restantes: (2831, 5000)
# Processados 1174 stargazers. Números de nodes/edges 1183 2824
# Requisições restantes: (2830, 5000)
# Processados 1175 stargazers. Números de nodes/edges 1183 2824
# Requisições restantes: (2828, 5000)
# Processados 1176 stargazers. Números de nodes/edges 1183 2824
# Requisições restantes: (2827, 5000)
# Processados 1177 stargazers. Números de nodes/edges 1183 2824
# Requisições restantes: (2826, 5000)
# Processados 1178 stargazers. Números de nodes/edges 1183 2824
# Requisições restantes: (2825, 5000)
# Processados 1179 stargazers. Números de nodes/edges 1183 2825
# Requisições restantes: (2824, 5000)
# Processados 1180 stargazers. Números de nodes/edges 1183 2825
# Requisições restantes: (2823, 5000)
# Processados 1181 stargazers. Números de nodes/edges 1183 2825
# Requisições restantes: (2822, 5000)
# Processados 1182 stargazers. Números de nodes/edges 1183 2825
# Requisições restantes: (2821, 5000)

# %% [markdown]
# ### 2.4 Visualizando grafo
# Agora podemos visualizar nosso grafo.
#
# Antes vamos fazer um backup e trabalhar com um grafo cópia para não alterar o original. Vamos salvar o arquivo com a extensão .graphml para podermos utilizar um outro programa para gerar a visualização, o Gephi. Por hora, vamos salvar o arquivo e remover o no de repositório.

# %%
# exportando grafo original
nx.write_graphml(graph, "original.graphml")

# cópia do grafo original
new_graph = graph.copy()

# removendo nosso repositório do grafo
new_graph.remove_node('Mining-the-Social-Web(repo)')

# %%
# outra cópia para retirar os nós sem arestas
clean_graph = new_graph.copy()

# remove os nós sem arestas
for node in new_graph.nodes:
  counter = 0
  for edge in new_graph.edges:
    if(node == edge[0] or node == edge[1]):
      counter = counter + 1
  
  if(counter == 0):
    clean_graph.remove_node(node)
    
print(nx.info(clean_graph))
# Out:
# Name: Interest graph of a repo
# Type: DiGraph
# Number of nodes: 722
# Number of edges: 1643
# Average in degree:   2.2756
# Average out degree:   2.2756

# %%
# novo grafo
nx.write_graphml(clean_graph, "final.graphml")

# %% [markdown]
# Vamos ver como está nosso grafo. Antes de gerar a visualização, podemos remover nosso repositório do grafo, por ser um outlier (todos se conectam com ele). Após isso podemos fazer algumas análises:
# - Qual usuário possui mais seguidores nessa rede,
# - Qual possui menos
# - Quem segue mais
# - Quem segue menos

# %%
from operator import itemgetter

# total de seguidores
followers = [edge for edge in clean_graph.edges(data=True) if edge[2]['type'] == 'follows']
print("Total de seguidores:", len(followers))

# total de seguidores do dono do repositório
ptwobruseell_followers = [edge for edge in clean_graph.edges(data=True) if edge[2]['type'] == 'follows' and edge[1] == "ptwobrussell(user)"]
print("Total de seguidores de ptwobruseell:", len(ptwobruseell_followers))

# a user who follows many but not followed back by many
print(len(graph.out_edges('mcanthony(user)')))
print(len(graph.in_edges('mcanthony(user)')))

# a user who is followed by many but does not follow back
print(len(graph.out_edges('angusshire(user)')))
print(len(graph.in_edges('angusshire(user)')))

# 10 usuários que possuem mais seguidores
top_10 = sorted([n for n in clean_graph.degree()], key=itemgetter(1), reverse=True)[:10]
print(top_10)
# Out:
# Total de seguidores: 1643
# Total de seguidores de ptwobruseell: 129
# 32
# 4
# 495
# 24
# [('angusshire(user)', 518), ('kenneth-reitz(user)', 174), ('ptwobrussell(user)', 129), ('VagrantStory(user)', 107), ('rohithadassanayake(user)', 70), ('trietptm(user)', 70), ('daimajia(user)', 42), ('mcanthony(user)', 35), ('JT5D(user)', 33), ('hammer(user)', 28)]
